# %%
# Import the necessary packages:

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create the Text using cv2.putText:

text_image = np.zeros((100,500),dtype = 'uint8')
font = cv2.FONT_HERSHEY_COMPLEX_SMALL = 5
cv2.putText(text_image,"VISHWA RATHINAM",(5,70),font,2,(255),8,cv2.LINE_AA)
plt.title("Original Text Image")
plt.imshow(text_image,'magma')
plt.axis('off')
# Out:
# (-0.5, 499.5, 99.5, -0.5)

# %%
# Create the structuring element:

kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(7,7))

# %%
# Erode the image:

image_erode = cv2.erode(text_image,kernel)
plt.title("Eroded Text Image")
plt.imshow(image_erode,'magma')
plt.axis('off')
# Out:
# (-0.5, 499.5, 99.5, -0.5)

# %%
# Dilate the image:

image_dilate = cv2.dilate(text_image,kernel)
plt.title("Dilated Text Image")
plt.imshow(image_dilate,'magma')
plt.axis('off')
# Out:
# (-0.5, 699.5, 99.5, -0.5)
